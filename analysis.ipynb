# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3eee4956-8783-435e-9607-3fa11ff343ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3eee4956-8783-435e-9607-3fa11ff343ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
# !pip install seaborn

# %%
df[df['SIXERS'] > 80][['PLAYER NAME', 'SIXERS']]
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 28  Gilchrist, AC      86
# 82     Pathan, YK      81
# 88      Raina, SK      97
# 97     Sharma, RG      82

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x = 'AGE', y = 'SOLD PRICE', data = df)
plt.show()

# %%
df.drop('Sl.NO.', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PLAYER NAME      0
# AGE              0
# COUNTRY          0
# TEAM             0
# PLAYING ROLE     0
# T-RUNS           0
# T-WKTS           0
# ODI-RUNS-S       0
# ODI-SR-B         0
# ODI-WKTS         0
# ODI-SR-BL        0
# CAPTAINCY EXP    0
# RUNS-S           0
# HS               0
# AVE              0
# SR-B             0
# SIXERS           0
# RUNS-C           0
# WKTS             0
# AVE-BL           0
# ECON             0
# SR-BL            0
# AUCTION YEAR     0
# BASE PRICE       0
# SOLD PRICE       0
# dtype: int64

# %%
sns.histplot(df['SOLD PRICE'], bins=20, kde=True)
plt.show()

# %%
sns.boxplot(x='AGE', y='SOLD PRICE', data=df)
plt.show()

# %%
sns.histplot(df['SIXERS'], kde=True)
plt.show()

# %%
sns.scatterplot(x='SIXERS', y='SOLD PRICE', data=df)
plt.show()

# %%
influential_features = ['AGE', 'SIXERS', 'SOLD PRICE', 'T-RUNS']
sns.pairplot(df[influential_features])
plt.show()

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER NAME    130 non-null    object
#  1   AGE            130 non-null    int64
#  2   COUNTRY        130 non-null    object
#  3   TEAM           130 non-null    object
#  4   PLAYING ROLE   130 non-null    object
#  5   T-RUNS         130 non-null    int64
#  6   T-WKTS         130 non-null    int64
#  7   ODI-RUNS-S     130 non-null    int64
#  8   ODI-SR-B       130 non-null    float64
#  9   ODI-WKTS       130 non-null    int64
#  10  ODI-SR-BL      130 non-null    float64
#  11  CAPTAINCY EXP  130 non-null    int64
#  12  RUNS-S         130 non-null    int64
#  13  HS             130 non-null    int64
#  14  AVE            130 non-null    float64
#  15  SR-B           130 non-null    float64
#  16  SIXERS         130 non-null    int64
# ...

# %%
df['PLAYER NAME'][:10]
df.loc[0:5, ['PLAYER NAME', 'SOLD PRICE']]
# Out:
#     PLAYER NAME  SOLD PRICE
# 0   Abdulla, YA       50000
# 1  Abdur Razzak       50000
# 2   Agarkar, AB      350000
# 3     Ashwin, R      850000
# 4  Badrinath, S      800000
# 5    Bailey, GJ       50000

# %%
df['TEAM'].value_counts()
pd.crosstab(df['PLAYING ROLE'], df['COUNTRY'])
# Out:
# COUNTRY       AUS  BAN  ENG  IND  NZ  PAK  SA  SL  WI  ZIM
# PLAYING ROLE
# Allrounder      6    0    2    7   4    2   7   4   3    0
# Batsman         9    0    1   18   2    2   3   2   2    0
# Bowler          6    1    0   23   0    4   4   5   1    0
# W. Keeper       1    0    0    5   1    1   2   1   0    1

# %%
df.sort_values(by='SOLD PRICE', ascending=False).head()
# Out:
#        PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 127   Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 50        Kohli, V    1     IND    RCB      Batsman     491       0
# 111  Tendulkar, SR    3     IND     MI      Batsman   15470      45
# 93       Sehwag, V    2     IND     DD      Batsman    8178      40
# 113     Tiwary, SS    1     IND    MI+      Batsman       0       0
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  \
# 127        8051     87.58       109  ...  131.88      67     569    23
# 50         3590     86.31         2  ...  119.29      49     345     4
# 111       18426     86.23       154  ...  119.22      24      58     0
# 93         8090    104.68        95  ...  167.32      79     226     6
# 113          49     87.50         0  ...  119.60      32       0     0
#
#      AVE-BL   ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 127   24.74   7.02  21.13          2011      400000     1800000
# ...

# %%
df[(df['SOLD PRICE'] > 500000) & (df['AGE'] < 3)][['PLAYER NAME', 'SOLD PRICE']]
# Out:
#           PLAYER NAME  SOLD PRICE
# 3           Ashwin, R      850000
# 4        Badrinath, S      800000
# 7       Bollinger, DE      700000
# 8            Botha, J      950000
# 15          Dhoni, MS     1500000
# 23        Flintoff, A     1550000
# 24         Gambhir, G      725000
# 26          Gayle, CH      800000
# 30    Harbhajan Singh      850000
# 37         Hussey, DJ      625000
# 39         Jadeja, RA      950000
# 43            Kaif, M      675000
# 47        Karthik, KD      525000
# 50           Kohli, V     1800000
# 51           Kumar, P      800000
# 55             Lee, B      900000
# 59        Mathews, AD      950000
# 60       McCullum, BB      700000
# 66      Mohammad Asif      650000
# 67         Morkel, JA      675000
# 71          Nayar, AM      800000
# 72           Nehra, A      850000
# 77          Oram, JDP      675000
# 81         Pathan, IK      925000
# 83      Pietersen, KP     1550000
# 88          Raina, SK      650000
# ...

# %%
sns.barplot(x='AGE', y='SOLD PRICE', data=df)
plt.show()

# %%
cols = ['AGE', 'SIXERS', 'SOLD PRICE', 'T-RUNS']
sns.pairplot(df[cols])
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
